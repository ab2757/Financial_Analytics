# %% [markdown]
# # Decision Tree
#
# Tree based learning algorithms are considered to be one of the best and mostly used supervised learning methods. Tree based methods empower predictive models with high accuracy, stability and ease of interpretation. Unlike linear models, they map non-linear relationships quite well. They are adaptable at solving any kind of problem at hand (classification or regression).
#
# Methods like decision trees, random forest, gradient boosting are being popularly used in all kinds of data science problems. Hence, for every analyst (fresher also), it’s important to learn these algorithms and use them for modeling.
#
# This tutorial is meant to help beginners learn tree based modeling from scratch. After the successful completion of this tutorial, one is expected to become proficient at using tree based algorithms and build predictive models.

# %% [markdown]
# **Decision tree** is a type of supervised learning algorithm (having a pre-defined target variable) that is mostly used in classification problems.
#
# In this technique, we split the population or sample into two or more homogeneous sets (or sub-populations) based on most significant splitter / differentiator in input variables.
#
# It works for both categorical and continuous input and output variables.

# %% [markdown]
# # Applications
#
# For a bank to consider whether or not to offer someone a loan they often go through a sequential list of questions to figure out if it is safe to give said loan to an individual.
#
# * Those questions can start as simple as what kind of income does the person have?
# * If it is between $30–70k they move on to the next question.
# * How long have they held their current job? If 1–5 years it leads to their next question of do they make their credit card payments?
# * If yes then they offer the Loan and if no they do not.
#
# This process at its most basic form is a **Decision Tree**.
#
# A decision tree is a largely used non-parametric effective machine learning modeling technique for regression and classification problems. To find solutions a decision tree makes sequential, hierarchical decision about the outcomes variable based on the predictor data.

# %% [markdown]
# # Types of Decision Trees
#
# Types of decision tree is based on the type of target variable we have. It can be of two types:
#
# * **Categorical Variable Decision Tree**:
#     * Decision Tree which has categorical target variable then it called as categorical variable decision tree.
#     * Example:- Another key factor to consider is customer churn. If customer will churn then "Yes" else "No".
#
#
#
# * **Continuous Variable Decision Tree**:
#     * Decision Tree has continuous target variable then it is called as Continuous Variable Decision Tree.
#
#     * Example:- Let’s say we have a problem to predict whether a customer will pay his renewal premium with an insurance company (yes/ no). Here we know that income of customer is a significant variable but insurance company does not have income details for all customers. Now, as we know this is an important variable, then we can build a decision tree to predict customer income based on occupation, product and various other variables. In this case, we are predicting values for continuous variable.

# %% [markdown]
# # Advantages of Decision Tree.
#
# * Decision Trees are easy to explain.It results in a set of rules.
#
# * It follows the same approach as humans generally follow while making decisions.
#
# * Interpretation of a complex Decision Tree model can be simplified by its visualizations. Even a naive person can understand logic.
#
# * The number of hyper-parameters to be tuned is almost null.
#
# # Drawbacks of Decision Tree.
# * There is a high probability of overfitting in Decision Tree.
#
# * Generally, it gives low prediction accuracy for a dataset as compared to other machine learning algorithms.
#
# * Information gain in a decision tree with categorical variables gives a biased response for attributes with greater no. of categories.
#
# * Calculations can become complex when there are many class labels.

# %% [markdown]
# # How Decision Tree Algorithm works?
# Decision Tree algorithm belongs to the family of supervised learning algorithms.
#
# Unlike other supervised learning algorithms, decision tree algorithm can be used for solving regression and classification problems too.
#
#
# The general motive of using Decision Tree is to create a training model which can use to predict class or value of target variables by learning decision rules inferred from prior data(training data).
#
#
# The understanding level of Decision Trees algorithm is so easy compared with other classification algorithms.
#
# The decision tree algorithm tries to solve the problem, by using tree representation. Each internal node of the tree corresponds to an attribute, and each leaf node corresponds to a class label.
#
# # Pseudo code.
# * Place the best attribute of the dataset at the root of the tree.
# * Split the training set into subsets. Subsets should be made in such a way that each subset contains data with the same value for an attribute.
# * Repeat step 1 and step 2 on each subset until you find leaf nodes in all the branches of the tree.

# %% [markdown]
# ### Assumptions while creating Decision Tree
#
# The below are the some of the assumptions we make while using Decision tree:
#
#    * At the beginning, the whole training set is considered as the root.
#    * Feature values are preferred to be categorical. If the values are continuous then they are discretized prior to building the model.
#    * Records are distributed recursively on the basis of attribute values.
#    * Order to placing attributes as root or internal node of the tree is done by using some statistical approach.

# %% [markdown]
# # Good Reads :
# https://www.analyticsvidhya.com/blog/2016/04/complete-tutorial-tree-based-modeling-scratch-in-python/
#
# https://medium.com/@rishabhjain_22692/decision-trees-it-begins-here-93ff54ef134

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('1IQOtJ4NI_0')

# %%
YouTubeVideo('mQaAPoRGOcs')

# %% [markdown]
# # Real Life Example :
# You are manager in a bank. You aim to accomplist the following for this study:
#
# 1. Identify and visualize which factors contribute to bank customer churn:
#
# 2. Build a prediction model that will perform the following:
#     * Classify if a customer is going to churn or not
#     * Based on model performance, choose a model that will predict the probability to the churn to make it easier for customer service to target low hanging fruits in their efforts to prevent churn

# %% [markdown]
# # What is Churn ?
# Customer churn, or attrition, measures the number of customers who discontinue a service or stop buying products in a given time period.
#
# Measuring churn, understanding the underlying reasons and being able to anticipate and manage risks associated to customer churn are key areas for continuous increase in business value.

# %% [markdown]
# # Types of Churn :
# There are two types of Churn :
# * Soft Churn : Soft churn refers to when a customer has not transacted with the business for a certain period. Transactions may or may not happen in future.
#
# * Hard Churn : Hard churn refers to the closure of an account by a customer. No more transactions can happen now.

# %% [markdown]
# # PREVENTING BANK CUSTOMER CHURN!

# %% [markdown]
# ## 1. Data set review & preparation
#
# In this section we will seek to explore the structure of our data:
# 1. To understand the input data set
# 2. And to prepare the data for exploratory and prediction tasks

# %% [markdown]
# Let's first import the required libraries.

# %%
## REQUIRED LIBRARIES
import numpy as np
import pandas as pd

# For visualization
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

import warnings
warnings.filterwarnings("ignore")


#pd.options.display.max_rows = None
#pd.options.display.max_columns = None

# %% [markdown]
# # 1. Read the data

# %%
# Read the data frame
data = pd.read_csv('Data/Hard_Churn_Modelling.csv')
print(data.shape)
# Out:
# (10000, 12)

# %% [markdown]
# The Df has 10000 rows with 12 attributes.
#
# # 2. Data Exploration
# We review this further to identify what attributes will be necessary and what data manipulation needs to be carried out before Exploratory analysis and prediction modelling

# %%
# Check columns list and missing values
data.isnull().sum()
# Out:
# CustomerId         0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# Well, no missing values!!!

# %% [markdown]
# We can check the count of categories of each column to confirm which column is actually categorical. For this, we will make use of pandas' nunique() which will count number of  unique values in each column of the dataframe.

# %%
# Get unique count for each variable
data.nunique()
# Out:
# CustomerId         10000
# CreditScore          460
# Geography              3
# Gender                 2
# Age                   70
# Tenure                11
# Balance             6382
# NumOfProducts          4
# HasCrCard              2
# IsActiveMember         2
# EstimatedSalary     9999
# Exited                 2
# dtype: int64

# %% [markdown]
# From the above, we will not require the first variable(CustomerID) as it is a unique identifier which is specific to each customer.

# %%
# Drop the columns as explained above
data = data.drop(["CustomerId"], axis = 1)

# %%
# Review the top rows of what is left of the data frame
print(data.head())
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %% [markdown]
# From the above, a couple of question linger:
# 1. The data appears to be a snapshot as some point in time e.g. the balance is for a given date which leaves a lot of questions:
#     * What date is it and of what relevance is this date
#     * Would it be possible to obtain balances over a period of time as opposed to a single date.
# 2. There are customers who have exited but still have a balance in their account! What would this mean? Could they have exited from a product and not the bank?
# 3. What does being an active member mean and are there difference degrees to it? Could it be better to provide transaction count both in terms of credits and debits to the account instead?
# 4. A break down to the products bought into by a customer could provide more information topping listing of product count
#
# For this exercise, we proceed to model without context even though typically having context and better understanding of the data extraction process would give better insight and possibly lead to better and contextual results of the modelling process

# %% [markdown]
# Sometimes, we need to check the data types of each column of a dataframe. For this, we use .dtypes method of pandas dataframe

# %%
# Check variable data types
print(data.dtypes)
# Out:
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %% [markdown]
# So we mostly have numerical variables and 2 categorical variables.

# %% [markdown]
# ## 3. Data Visualization
# Here our main interest is to visualize as to how the given attributes relate too the 'Exit' status.

# %%
labels = 'Exited', 'Retained'
data_exited = data.loc[data['Exited']==1,'Exited']
data_retained = data.loc[data['Exited']==0,'Exited']
sizes = [data_exited.shape[0], data_retained.shape[0]]
print(sizes)

# Plot a pie chart
fig1, ax1 = plt.subplots(figsize=(10, 8))
ax1.pie(sizes, explode=(0,0.1), labels=labels, autopct='%1.1f%%',shadow=True, startangle=90)
ax1.axis('equal')
plt.title("Proportion of customer churned and retained", size = 20)
plt.show()
# Out:
# [2037, 7963]

# %% [markdown]
# So about 20% of the customers have churned. So the baseline model could be to predict that 20% of the customers will churn.
#
# Given 20% is a small number,  we need to ensure that the chosen model does predict with great accuracy this 20% as it is of interest to the bank to identify and keep this bunch as opposed to accurately predicting the customers that are retained.

# %% [markdown]
# ### Code Explanation
#
# We want to create a pie chart using matplotlib's pie(). For this, we need to create a variable 'sizes' which will contain the length of each category.
#
# Also, we want the churn part to be exploding little outside. For this, we passed argument explode with values (0,0.01).

# %% [markdown]
# Let's also create some plots for categorical variables to see their relationship with the target variable.

# %%
    # We first review the 'Status' relation with categorical variables
    fig, axarr = plt.subplots(2, 2, figsize=(20, 12))
    sns.countplot(x='Geography', hue = 'Exited',data = data, ax=axarr[0][0])
    sns.countplot(x='Gender', hue = 'Exited',data = data, ax=axarr[0][1])
    sns.countplot(x='HasCrCard', hue = 'Exited',data = data, ax=axarr[1][0])
    sns.countplot(x='IsActiveMember', hue = 'Exited',data = data, ax=axarr[1][1])

# %% [markdown]
# We note the following:
# * Majority of the data is from persons from France. However, the proportion of churned customers is with inversely related to the population of customers alluding to the bank possibly having a problem (maybe not enough customer service resources allocated) in the areas where it has fewer clients.
# * The proportion of female customers churning is also greater than that of male customers
# * Interestingly, majority of the customers that churned are those with credit cards. Given that majority of the customers have credit cards could prove this to be just a coincidence.
# * Unsurprisingly the inactive members have a greater churn. Worryingly is that the overall proportion of inactive mebers is quite high suggesting that the bank may need a program implemented to turn this group to active customers as this will definately have a positive impact on the customer churn.

# %% [markdown]
# Now, it's time to plot some boxplots for numeric variable with the target variable.

# %%
    # Relations based on the continuous data attributes
    fig, axarr = plt.subplots(3, 2, figsize=(20, 12))
    sns.boxplot(y='CreditScore',x = 'Exited', hue = 'Exited',data = data, ax=axarr[0][0])
    sns.boxplot(y='Age',x = 'Exited', hue = 'Exited',data = data, ax=axarr[0][1])
    sns.boxplot(y='Tenure',x = 'Exited', hue = 'Exited',data = data, ax=axarr[1][0])
    sns.boxplot(y='Balance',x = 'Exited', hue = 'Exited',data = data, ax=axarr[1][1])
    sns.boxplot(y='NumOfProducts',x = 'Exited', hue = 'Exited',data = data, ax=axarr[2][0])
    sns.boxplot(y='EstimatedSalary',x = 'Exited', hue = 'Exited',data = data, ax=axarr[2][1])

# %% [markdown]
# We note the following:
# * There is no significant difference in the credit score distribution between retained and churned customers.
# * The older customers are churning at more than the younger ones alluding to a difference in service preference in the age categories. The bank may need to review their target market or review the strategy for retention between the different age groups
# * With regard to the tenure, the clients on either extreme end (spent little time with the bank or a lot of time with the bank) are more likely to churn compared to those that are of average tenure.
# *  Worryingly, the bank is losing customers with significant bank balances which is likely to hit their available capital for lending.
# * Neither the product nor the salary has a significant effect on the likelihood to churn.

# %% [markdown]
# ### For better understanding on Boxplot, below is a good read :
#
# https://towardsdatascience.com/understanding-boxplots-5e2df7bcbd51

# %% [markdown]
# ## 4. Feature engineering
# We seek to add features that are likely to have an impact on the probability of churning.
#
# Few such features could be :
# * **BalanceSalaryRatio** : Ratio of Balance and Salary
# * **TenureByAge** : Ratio of Tenure and Age
# * **CreditScoreGivenAge** : Ratio of Credit Score and Age

# %%
data['BalanceSalaryRatio'] = data.Balance/data.EstimatedSalary
sns.boxplot(y='BalanceSalaryRatio',x = 'Exited', hue = 'Exited',data = data)
plt.ylim(-1, 5)
# Out:
# (-1, 5)

# %% [markdown]
# We have seen that the salary has little effect on the chance of a customer churning. However as seen above, the ratio of the bank balance and the estimated salary indicates that customers with a higher balance salary ratio churn more which would be worrying to the bank as this impacts their source of loan capital.

# %%
# Given that tenure is a 'function' of age, we introduce a variable aiming to standardize tenure over age:
data['TenureByAge'] = data.Tenure/(data.Age)
sns.boxplot(y='TenureByAge',x = 'Exited', hue = 'Exited',data = data)
plt.ylim(-1, 1)
plt.show()

# %%
#Lastly we introduce a variable to capture credit score given age to take into account credit behaviour visavis adult life
data['CreditScoreGivenAge'] = data.CreditScore/(data.Age)

# %%
# Resulting Data Frame
print(data.head())
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited  BalanceSalaryRatio  \
# 0          1               1        101348.88       1            0.000000
# 1          0               1        112542.58       0            0.744677
# 2          1               0        113931.57       1            1.401375
# 3          0               0         93826.63       0            0.000000
# 4          1               1         79084.10       0            1.587055
#
#    TenureByAge  CreditScoreGivenAge
# 0     0.047619            14.738095
# ...

# %% [markdown]
# ## 5. Data prep for model fitting

# %% [markdown]
# Let's divide our all variables into categorical and continuous list.

# %%
# Arrange columns by data type for easier manipulation
continuous_vars = ['CreditScore',  'Age', 'Tenure', 'Balance','NumOfProducts', 'EstimatedSalary', 'BalanceSalaryRatio',
                   'TenureByAge','CreditScoreGivenAge']
cat_vars = ['HasCrCard', 'IsActiveMember','Geography', 'Gender']
data = data[['Exited'] + continuous_vars + cat_vars]
print(data.head())
# Out:
#    Exited  CreditScore  Age  Tenure    Balance  NumOfProducts  \
# 0       1          619   42       2       0.00              1
# 1       0          608   41       1   83807.86              1
# 2       1          502   42       8  159660.80              3
# 3       0          699   39       1       0.00              2
# 4       0          850   43       2  125510.82              1
#
#    EstimatedSalary  BalanceSalaryRatio  TenureByAge  CreditScoreGivenAge  \
# 0        101348.88            0.000000     0.047619            14.738095
# 1        112542.58            0.744677     0.024390            14.829268
# 2        113931.57            1.401375     0.190476            11.952381
# 3         93826.63            0.000000     0.025641            17.923077
# 4         79084.10            1.587055     0.046512            19.767442
#
#    HasCrCard  IsActiveMember Geography  Gender
# 0          1               1    France  Female
# 1          0               1     Spain  Female
# ...

# %% [markdown]
# Now, we will convert our categorical data into numerical data so that data can be used for modelling.

# %%
dummy_Geography = pd.get_dummies(data['Geography'], prefix='Geography')
data = pd.concat([data, dummy_Geography], axis=1)
data = data.drop('Geography',axis=1)
print(data.head())
# Out:
#    Exited  CreditScore  Age  Tenure    Balance  NumOfProducts  \
# 0       1          619   42       2       0.00              1
# 1       0          608   41       1   83807.86              1
# 2       1          502   42       8  159660.80              3
# 3       0          699   39       1       0.00              2
# 4       0          850   43       2  125510.82              1
#
#    EstimatedSalary  BalanceSalaryRatio  TenureByAge  CreditScoreGivenAge  \
# 0        101348.88            0.000000     0.047619            14.738095
# 1        112542.58            0.744677     0.024390            14.829268
# 2        113931.57            1.401375     0.190476            11.952381
# 3         93826.63            0.000000     0.025641            17.923077
# 4         79084.10            1.587055     0.046512            19.767442
#
#    HasCrCard  IsActiveMember  Gender  Geography_France  Geography_Germany  \
# 0          1               1  Female                 1                  0
# ...

# %%
dummy_Gender = pd.get_dummies(data['Gender'], prefix='Gender')
data = pd.concat([data, dummy_Gender], axis=1)
data = data.drop('Gender',axis=1)
print(data.head())
# Out:
#    Exited  CreditScore  Age  Tenure    Balance  NumOfProducts  \
# 0       1          619   42       2       0.00              1
# 1       0          608   41       1   83807.86              1
# 2       1          502   42       8  159660.80              3
# 3       0          699   39       1       0.00              2
# 4       0          850   43       2  125510.82              1
#
#    EstimatedSalary  BalanceSalaryRatio  TenureByAge  CreditScoreGivenAge  \
# 0        101348.88            0.000000     0.047619            14.738095
# 1        112542.58            0.744677     0.024390            14.829268
# 2        113931.57            1.401375     0.190476            11.952381
# 3         93826.63            0.000000     0.025641            17.923077
# 4         79084.10            1.587055     0.046512            19.767442
#
#    HasCrCard  IsActiveMember  Geography_France  Geography_Germany  \
# 0          1               1                 1                  0
# ...

# %% [markdown]
# ## 6. Model fitting and selection
# We will fit the **Decision Tree** model.
#
# DecisionTreeClassifier can be imported from sklearn's tree module to run a Decision Tree.
#
# We will also import libraries for train_test_split and metrics to calulcate the performance of the model.

# %%
# Load libraries
import pandas as pd
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %%
X = data.drop('Exited',axis=1) # Features
y = data.Exited # Target variable
print(X.shape)
print(y.shape)
# Out:
# (10000, 16)
# (10000,)

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=1) # 75% training and 25% test

# %%
# Create Decision Tree classifer object
clf = DecisionTreeClassifier(max_depth=1)

# Train Decision Tree Classifer
clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.792

# %% [markdown]
# ### Code Explanation
# * Step 1 : DecisionTreeClassifier() is used to instantiate an object clf with max_depth = 1. max_depth is one of the hyperparameters of Decision Tree.
# * Step 2 : We can now fit/train the model by using X_train and y_train
# * Step 3 : After this, we preidict the output using .predict() on test dataset.
# * Step 4 : We can check the performance of the test results by using accuracy_score() from sklearn's metrics module.

# %% [markdown]
# Well, we got a classification rate of 79.2%, considered as good accuracy. We can improve this accuracy by tuning the parameters in the Decision Tree Algorithm.
#
# But before doing that, let's check if this accuracy is good enough or not. We can do this by checking confusion matrix on test set.

# %%
# Check the confusion matrix of the prediction for the testing set
print(metrics.confusion_matrix(y_test,y_pred))
# Out:
# [[1980    0]
#  [ 520    0]]

# %% [markdown]
# We can see that the model is predicting all 0, i.e., all are retained which is giving good accuracy but this is not the correct way to check the performance of such a model.
#
# We can use another metric 'Classification Report' which will tell us precision and recall.

# %%
print(metrics.classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      1.00      0.88      1980
#            1       0.00      0.00      0.00       520
#
#     accuracy                           0.79      2500
#    macro avg       0.40      0.50      0.44      2500
# weighted avg       0.63      0.79      0.70      2500

# %% [markdown]
# We can see that the model is predicting all 0, i.e., all are retained which is giving good accuracy but 0 precision and 0 recall which signifies that it is a very bad model.

# %% [markdown]
# ## Visualizing the Decision Tree
# Now, it's time to visualize the decision tree.
#
# You need to install pydotplus and graphviz. These can be installed with your package manager and pip.
#
# **Graphviz** is a tool for drawing graphics using dot files. **Pydotplus** is a module to Graphviz’s Dot language.

# %%
# Go through the below video to install Graphviz and Pydotplus
YouTubeVideo('z-AGmGmR6Z8')

# %%
from sklearn.tree import export_graphviz
from sklearn.externals.six import StringIO  
from IPython.display import Image  
import pydotplus

dot_data = StringIO()
export_graphviz(clf, out_file=dot_data, filled=True, rounded=True, special_characters=True,
                feature_names = X.columns.tolist(),class_names=['0','1'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('decision_tree.png')
Image(graph.create_png())

# %% [markdown]
# ### Code Explanation
# * For visualizing a decision tree, we need to first import some libraries.
# * After this, we create dot_data in which we need to save theo output.
# * Then, we pass all the required arguments to the export_graphviz() and the clasifier we make for DecisioTreeClassifier.
# * Once, data is plotted, we will convert dot data into grap.

# %% [markdown]
# ## Decision Tree Interpretation:
# You can see a simple decision tree above and can interpret the following :
# * The variable to split is "Age"
# * Check if Age <= 42.5 years
# * If True, predict Class=0
# * If False, predict Class=0
#
# This tree also shows the values of gini for each leaf and number of data samples for each class at each leaf.

# %% [markdown]
# ### Build another tree
# Let's build another tree. This time with max_depth = 3 and criterion = "entropy".

# %%
# Create Decision Tree classifer object
clf2 = DecisionTreeClassifier(criterion="entropy", max_depth=3)

# Train Decision Tree Classifer
clf2.fit(X_train,y_train)

#Predict the response for test dataset
y_pred2 = clf2.predict(X_test)

# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred2))
# Out:
# Accuracy: 0.8404

# %%
# Check the confusion matrix of the prediction for the testing set
print(metrics.confusion_matrix(y_test,y_pred2))
# Out:
# [[1962   18]
#  [ 381  139]]

# %%
print(metrics.classification_report(y_test,y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.99      0.91      1980
#            1       0.89      0.27      0.41       520
#
#     accuracy                           0.84      2500
#    macro avg       0.86      0.63      0.66      2500
# weighted avg       0.85      0.84      0.80      2500

# %% [markdown]
# Great, now accuracy is increased and precision and recall are not zero also.
#
# Let's visualize this tree.

# %%
from sklearn.tree import export_graphviz
from sklearn.externals.six import StringIO  
from IPython.display import Image  
import pydotplus

dot_data = StringIO()
export_graphviz(clf2, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True,feature_names = X.columns.tolist(),class_names=['0','1'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('decision_tree2.png')
Image(graph.create_png())

# %% [markdown]
# We should check cross validation score by using 10 folds here in the cross_val_score() from sklearn's model_selection module.

# %%
# Import the function for implementing cross validation
from sklearn.model_selection import cross_val_score

# %%
# Use that function to print the cross validation score for 10 folds
print(cross_val_score(clf,X_train,y_train,cv=10))
# Out:
# [0.797603 0.797603 0.797603 0.797333 0.797333 0.797333 0.797333 0.798398
#  0.798398 0.798398]

# %% [markdown]
# We can check the cross-validation score by using cross_val_score() with cv = 10.
#
# We can see that all cross-validation scores are similar.

# %% [markdown]
# ## What is grid search?
# Grid search is the process of performing hyper parameter tuning in order to determine the optimal values for a given model.
#
# This is significant as the performance of the entire model is based on the hyper parameter values specified.

# %% [markdown]
# ## Why should you use it?
# If you work with ML, you know what a nightmare it is to stipulate values for hyper parameters.
#
# There are libraries that have been implemented, such as GridSearchCV of the sklearn library, in order to automate this process and make life a little bit easier for ML enthusiasts.

# %% [markdown]
# ## How does it work?
# Below is a python implementation of grid search using GridSearchCV of the sklearn library.

# %%
from sklearn.model_selection import GridSearchCV

gs_clf = GridSearchCV(estimator=DecisionTreeClassifier(random_state=1),
        param_grid={
            'max_depth': range(1,9,2),
            'min_samples_leaf': range(50,250,50),
        })

gs_clf.fit(X_train,y_train)

# print the best parameters found
print(gs_clf.best_params_)

# %% [markdown]
# ### Code Explanation :
# * For GridSearchCV, we need to provide a sklearn model(DecisionTreeClassifier).
# * For grid searching, we pass set of values to the hyperparameters.
# * Then, we fit the model and get the best parameters using some scoring function like accuracy.

# %% [markdown]
# ## Hyper Parameters:
# The best way to think about hyperparameters is like the settings of an algorithm that can be adjusted to optimize performance.
#
# While model parameters are learned during training — such as the slope and intercept in a linear regression — hyperparameters must be set by the data scientist before training.
#
# Some of the hyperparameters for Decision Tree :
#
# * **max_depth** : The first parameter to tune is max_depth. This indicates how deep the tree can be. The deeper the tree, the more splits it has and it captures more information about the data.
#
# * **min_samples_leaf** : min_samples_leaf is The minimum number of samples required to be at a leaf node. This parameter is similar to min_samples_splits, however, this describe the minimum number of samples of samples at the leafs, the base of the tree.
#
# * **max_features** : max_features represents the number of features to consider when looking for the best split.
#
# * **min_samples_split** : min_samples_split represents the minimum number of samples required to split an internal node. This can vary between considering at least one sample at each node to considering all of the samples at each node. When we increase this parameter, the tree becomes more constrained as it has to consider more samples at each node.

# %% [markdown]
# Best model comes up with max_depth as 7 and min_samples_leaf as 50.
#
# Let's build this model.

# %%
# Create Decision Tree classifer object
best_clf = DecisionTreeClassifier(max_depth=7,min_samples_leaf=50)

# Train Decision Tree Classifer
best_clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred3 = best_clf.predict(X_test)

# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred3))
# Out:
# Accuracy: 0.8608

# %%
# Check the confusion matrix of the prediction for the testing set
print(metrics.confusion_matrix(y_test,y_pred3))
# Out:
# [[1873  107]
#  [ 241  279]]

# %%
print(metrics.classification_report(y_test,y_pred3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.95      0.91      1980
#            1       0.72      0.54      0.62       520
#
#     accuracy                           0.86      2500
#    macro avg       0.80      0.74      0.77      2500
# weighted avg       0.85      0.86      0.85      2500

# %% [markdown]
# Great, now accuracy is increased and precision and recall are not zero also.
#
# Let's visualize this tree.

# %%
from sklearn.tree import export_graphviz
from sklearn.externals.six import StringIO  
from IPython.display import Image  
import pydotplus

dot_data = StringIO()
export_graphviz(best_clf, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True,feature_names = X.columns.tolist(),class_names=['0','1'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('decision_tree3.png')
Image(graph.create_png())

# %% [markdown]
# # Feature Importance
#
# In Data modelling, it is important to have an accurate model, but also equally important to have an interpretable model.
#
# Oftentimes, apart from wanting to know what our model’s house price prediction is, we also wonder why it is this high/low and which features are most important in determining the forecast.
#
# In predicting customer churn — it is very nice to have a model that is successfully predicting which customers are prone to churn, but identifying which variables are important can help us in early detection and maybe even improving the product/service!

# %% [markdown]
# ## Scikit-learn’s feature importances
#
# In decision trees, every node is a condition of how to split values in a single feature, so that similar values of the dependent variable end up in the same set after the split.
#
# The condition is based on Gini/information gain(entropy), while for regression trees its Variance.
#
# So when training a tree we can compute how much each feature contributes to decreasing the weighted impurity(Gini/Entropy/Variance).
#
# **feature\_importances\_** in *Scikit-Learn* is based on that logic.

# %% [markdown]
# Now, we will extract the Feature Importance value for each feature and plot it in descending order to check which features play more important role in building the model.

# %%
# Calculate feature importances
feature_importances = best_clf.feature_importances_

# Create a list of features: done
feature_list = list(X)

# Save the results inside a DataFrame using feature_list as an indnex
relative_importances = pd.DataFrame(index=feature_list, data=feature_importances, columns=["importance"])

# Sort values to learn most important features
relative_importances = relative_importances.sort_values(by="importance", ascending=False)

print(relative_importances)
# Out:
#                      importance
# Age                    0.411585
# NumOfProducts          0.263183
# IsActiveMember         0.131007
# Balance                0.057477
# BalanceSalaryRatio     0.057229
# Geography_Germany      0.053348
# Gender_Female          0.008258
# Gender_Male            0.006474
# CreditScore            0.005950
# EstimatedSalary        0.003899
# CreditScoreGivenAge    0.001590
# Tenure                 0.000000
# TenureByAge            0.000000
# HasCrCard              0.000000
# Geography_France       0.000000
# Geography_Spain        0.000000

# %%
relative_importances = relative_importances.sort_values(by="importance", ascending=True)
relative_importances.plot.barh(title="Feature Importances", figsize=(8,8))
plt.xlabel('Feature Importance Score')
plt.show()

# %%
# select only features with relative importance higher than 1%
selected_features = relative_importances[relative_importances.importance>0.01]
print(selected_features)

# create a list from those features: done
selected_list = selected_features.index

# transform both features_train and features_test components to include only selected features
X_train_selected = X_train[selected_list]
X_test_selected = X_test[selected_list]
# Out:
#                     importance
# Geography_Germany     0.053348
# BalanceSalaryRatio    0.057229
# Balance               0.057477
# IsActiveMember        0.131007
# NumOfProducts         0.263183
# Age                   0.411585

# %%
# Create Decision Tree classifer object
best_clf2 = DecisionTreeClassifier(max_depth=7,min_samples_leaf=50)

# Train Decision Tree Classifer
best_clf2.fit(X_train_selected,y_train)

#Predict the response for test dataset
y_pred4 = best_clf2.predict(X_test_selected)

# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred4))
# Out:
# Accuracy: 0.8608

# %%
# Check the confusion matrix of the prediction for the testing set
print(metrics.confusion_matrix(y_test,y_pred4))
# Out:
# [[1873  107]
#  [ 241  279]]

# %%
print(metrics.classification_report(y_test,y_pred4))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.95      0.91      1980
#            1       0.72      0.54      0.62       520
#
#     accuracy                           0.86      2500
#    macro avg       0.80      0.74      0.77      2500
# weighted avg       0.85      0.86      0.85      2500

# %% [markdown]
# This is our final best model as of now.
#
# Let's see how to predict the output for 10 new customers.

# %%
new_customer = X_test_selected.iloc[30:40,:].reset_index(drop=True)
print(new_customer)
# Out:
#    Geography_Germany  BalanceSalaryRatio    Balance  IsActiveMember  \
# 0                  0            8.659377  141038.57               0
# 1                  1            0.555769   91025.58               1
# 2                  0            1.480065  125190.86               1
# 3                  0            0.000000       0.00               0
# 4                  1            0.955409  109908.06               0
# 5                  0            3.592659  110929.96               1
# 6                  0            1.254399  157332.26               0
# 7                  1            1.418004  131694.97               1
# 8                  0            6.373737  143582.89               1
# 9                  0            0.000000       0.00               0
#
#    NumOfProducts  Age
# 0              2   28
# 1              2   34
# 2              1   37
# 3              1   55
# 4              2   37
# 5              1   40
# 6              1   45
# 7              1   52
# ...

# %%
best_clf2.predict(new_customer)
# Out:
# array([0, 0, 0, 1, 0, 0, 0, 1, 0, 0], dtype=int64)

# %% [markdown]
# Here, it is predicting that two customers are going to churn.
#
# But what's the probability ? Let's calculate the probability.

# %%
best_clf2.predict_proba(new_customer)
# Out:
# array([[0.976471, 0.023529],
#        [0.967742, 0.032258],
#        [0.933558, 0.066442],
#        [0.126761, 0.873239],
#        [0.804196, 0.195804],
#        [0.821429, 0.178571],
#        [0.520000, 0.480000],
#        [0.280000, 0.720000],
#        [0.933558, 0.066442],
#        [0.602151, 0.397849]])

# %% [markdown]
# The 1st column denotes the probability of being 0, i.e., RETAINED. And 2nd column denotes the probability of being 1, i.e., CHURN.
#
# We can see that 4th and 8th customer have highest probability of churn, but after that 7th and 10th customer also have high probabilities of being churned.

# %% [markdown]
# ### Overfitting
#
# Overfitting is a practical problem while building a decision tree model. The model is having an issue of overfitting is considered when the algorithm continues to go deeper and deeper in the to reduce the training set error but results with an increased test set error i.e, Accuracy of prediction for our model goes down. It generally happens when it builds many branches due to outliers and irregularities in data.
#
# #### Two approaches which we can use to avoid overfitting are:
#
#
# Over-fitting is the phenomenon in which the learning system tightly fits the given training data so much that it would be inaccurate in predicting the outcomes of the untrained data.
# In decision trees, over-fitting occurs when the tree is designed so as to perfectly fit all samples in the training data set. Thus it ends up with branches with strict rules of sparse data. Thus this effects the accuracy when predicting samples that are not part of the training set.
# One of the methods used to address over-fitting in decision tree is called pruning which is done after the initial training is complete. In pruning, you trim off the branches of the tree, i.e., remove the decision nodes starting from the leaf node such that the overall accuracy is not disturbed. This is done by segregating the actual training set into two sets: training data set, D and validation data set, V. Prepare the decision tree using the segregated training data set, D. Then continue trimming the tree accordingly to optimize the accuracy of the validation data set, V.
#
# Good read :  https://www.saedsayad.com/decision_tree_overfitting.htm

# %% [markdown]
# ##  For Continous target variables :
#
# Good read :https://www.geeksforgeeks.org/python-decision-tree-regression-using-sklearn/

# %% [markdown]
# # ENSEMBLE LEARNING
# Ensemble methods combine several decision trees classifiers to produce better predictive performance than a single decision tree classifier.
#
# The main principle behind the ensemble model is that a group of weak learners come together to form a strong learner, thus increasing the accuracy of the model.
#
# When we try to predict the target variable using any machine learning technique, the main causes of difference in actual and predicted values are noise, variance, and bias. Ensemble helps to reduce these factors (except noise, which is irreducible error).

# %% [markdown]
# Using techniques like **Bagging** and **Boosting** helps to decrease the variance and increased the robustness of the model. Combinations of multiple classifiers decrease variance, especially in the case of unstable classifiers, and may produce a more reliable classification than a single classifier.
#
# But before understanding Bagging and Boosting and how different classifiers are selected in the two algorithms, lets first talk about Bootstrapping.

# %% [markdown]
# # BOOTSTRAPPING
#
# Bootstrap refers to random sampling with replacement. Bootstrap allows us to better understand the bias and the variance with the dataset.
#
# Bootstrap involves random sampling of small subset of data from the dataset. This subset can be replace. The selection of all the example in the dataset has equal probability.
#
# This method can help to better understand the mean and standand deviation from the dataset.
#
# <img src = "Images/bootstrapping1.png">
#
# Having understood Bootstrapping we will use this knowledge to understand Bagging and Boosting.

# %% [markdown]
# # BAGGING
# Bootstrap Aggregation (or Bagging for short), is a simple and very powerful ensemble method. Bagging is the application of the Bootstrap procedure to a high-variance machine learning algorithm, typically decision trees.
#
# Suppose there are N observations and M features. A sample from observation is selected randomly with replacement(Bootstrapping).
# A subset of features are selected to create a model with sample of observations and subset of features.
#
# Feature from the subset is selected which gives the best split on the training data. This is repeated to create many models and every model is trained in parallel.
#
# Prediction is given based on the aggregation of predictions from all the models.

# %% [markdown]
# # BOOSTING
# Boosting refers to a group of algorithms that utilize weighted averages to make weak learners into stronger learners.
#
# Unlike bagging that had each model run independently and then aggregate the outputs at the end without preference to any model.
#
# Boosting is all about “teamwork”. Each model that runs, dictates what features the next model will focus on.
#
# <img src = "Images/boosting1.png">

# %% [markdown]
# ### Box 1:
# You can see that we have assigned equal weights to each data point and applied a decision stump to classify them as + (plus) or — (minus). The decision stump (D1) has generated vertical line at left side to classify the data points. We see that, this vertical line has incorrectly predicted three + (plus) as — (minus). In such case, we’ll assign higher weights to these three + (plus) and apply another decision stump.
#
# ### Box 2:
# Here, you can see that the size of three incorrectly predicted + (plus) is bigger as compared to rest of the data points. In this case, the second decision stump (D2) will try to predict them correctly. Now, a vertical line (D2) at right side of this box has classified three mis-classified + (plus) correctly. But again, it has caused mis-classification errors. This time with three -(minus). Again, we will assign higher weight to three — (minus) and apply another decision stump.
#
# ### Box 3:
# Here, three — (minus) are given higher weights. A decision stump (D3) is applied to predict these mis-classified observation correctly. This time a horizontal line is generated to classify + (plus) and — (minus) based on higher weight of mis-classified observation.
#
# ### Box 4:
# Here, we have combined D1, D2 and D3 to form a strong prediction having complex rule as compared to individual weak learner. You can see that this algorithm has classified these observation quite well as compared to any of individual weak learner.

# %% [markdown]
# # Which is the best, Bagging or Boosting?
#
# There’s not an outright winner; it depends on the data, the simulation and the circumstances.
#
# Bagging and Boosting decrease the variance of your single estimate as they combine several estimates from different models. So the result may be a model with higher stability.
#
# * If the problem is that the single model gets a very low performance, boosting could generate a combined model with lower errors.
#
# * If the difficulty of the single model is over-fitting, then Bagging is the best option.

# %% [markdown]
# # Random Forest
# Random Forest is an extension over bagging. It takes one extra step where in addition to taking the random subset of data, it also takes the random selection of features rather than using all features to grow trees.
#
# When you have many random trees, it's called **Random Forest**.

# %% [markdown]
# ## How does the algorithm work?
# It works in four steps:
#
# * Select random samples from a given dataset.
# * Construct a decision tree for each sample and get a prediction result from each decision tree.
# * Perform a vote for each predicted result.
# * Select the prediction result with the most votes as the final prediction.

# %% [markdown]
# ## Advantages of using Random Forest technique:
# * Handles higher dimensionality data very well.
# * Handles missing values and maintains accuracy for missing data.
#
# ## Disadvantages of using Random Forest technique:
# * Since final prediction is based on the mean predictions from subset trees, it won't give precise values for the regression model.

# %% [markdown]
# ## Random Forests vs Decision Trees
# Random forests is a set of multiple decision trees.
# Deep decision trees may suffer from overfitting, but random forests prevents overfitting by creating trees on random subsets.
# Decision trees are computationally faster.
# Random forests is difficult to interpret, while a decision tree is easily interpretable and can be converted to rules.

# %% [markdown]
# # Real Life Example :
# You are manager in a bank. You aim to accomplist the following for this study:
#
# 1. Identify and visualize which factors contribute to bank customer churn:
#
# 2. Build a prediction model that will perform the following:
#     * Classify if a customer is going to churn or not
#     * Based on model performance, choose a model that will predict the probability to the churn to make it easier for customer service to target low hanging fruits in their efforts to prevent churn

# %% [markdown]
# In Decision Tree case study, we used the data for **Hard Churn** where customers left the bank.
#
# In this example, we will consider **Soft Churn** where customers became inactive.

# %% [markdown]
# Let's first import the required libraries.

# %%
## REQUIRED LIBRARIES
import numpy as np
import pandas as pd

# For visualization
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # 1. Read the data

# %%
# Read the data frame
data = pd.read_csv('Data/Soft_Churn_Modelling.csv')
print(data.shape)
# Out:
# (10000, 14)

# %% [markdown]
# The Data has 10000 rows with 14 attributes.
#
# We review this further to identify what attributes will be necessary and what data manipulation needs to be carried out before Exploratory analysis and prediction modelling.

# %%
# Check columns list and missing values
data.isnull().sum()
# Out:
# CustomerId            0
# CreditScore           0
# Geography             0
# Gender                0
# Age                   0
# Tenure                0
# Balance               0
# NumOfProducts         0
# HasCrCard             0
# EstimatedSalary       0
# Num_Trans_12Months    0
# Num_Trans_6Months     0
# Num_Trans_3Months     0
# IsActiveMember        0
# dtype: int64

# %% [markdown]
# Well, no missing values!!!

# %%
# Get unique count for each variable
data.nunique()
# Out:
# CustomerId            10000
# CreditScore             460
# Geography                 3
# Gender                    2
# Age                      70
# Tenure                   11
# Balance                6382
# NumOfProducts             4
# HasCrCard                 2
# EstimatedSalary        9999
# Num_Trans_12Months      201
# Num_Trans_6Months       141
# Num_Trans_3Months       195
# IsActiveMember            2
# dtype: int64

# %% [markdown]
# From the above, we will not require the first variable(CustomerID) as it is a unique identifier which is specific to each customer.

# %%
# Drop the columns as explained above
data = data.drop(["CustomerId"], axis = 1)

# %% [markdown]
# We have same variables as before with addition of three more variables :
# * Num_Trans_12Months : Number of Transactions in last 12 months
# * Num_Trans_6Months : Number of Transactions in last 6 months
# * Num_Trans_3Months : Number of Transactions in last 3 months
#
# Target Variable is "**IsActiveMember**".
#
# So, we will not go into data visualization or data exploration. We will straightaway clean and manipulate the data for modelling and start creating the Random Forest model.

# %%
data['BalanceSalaryRatio'] = data.Balance/data.EstimatedSalary

data['TenureByAge'] = data.Tenure/(data.Age)

data['CreditScoreGivenAge'] = data.CreditScore/(data.Age)

# %%
# Resulting Data Frame
print(data.head())
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  EstimatedSalary  Num_Trans_12Months  Num_Trans_6Months  \
# 0          1        101348.88                 232                143
# 1          0        112542.58                 235                 88
# 2          1        113931.57                 208                102
# 3          0         93826.63                 163                 92
# 4          1         79084.10                 218                162
#
#    Num_Trans_3Months  IsActiveMember  BalanceSalaryRatio  TenureByAge  \
# ...

# %% [markdown]
# # 2. Data Exploration
# We review this further to identify what attributes will be necessary and what data manipulation needs to be carried out before Exploratory analysis and prediction modelling

# %%
# Arrange columns by data type for easier manipulation
continuous_vars = ['CreditScore',  'Age', 'Tenure', 'Balance','NumOfProducts', 'EstimatedSalary', 'BalanceSalaryRatio',
                   'TenureByAge','CreditScoreGivenAge', 'Num_Trans_12Months', 'Num_Trans_6Months','Num_Trans_3Months']
cat_vars = ['HasCrCard', 'Geography', 'Gender']
data = data[['IsActiveMember'] + continuous_vars + cat_vars]
print(data.head())
# Out:
#    IsActiveMember  CreditScore  Age  Tenure    Balance  NumOfProducts  \
# 0               1          619   42       2       0.00              1
# 1               1          608   41       1   83807.86              1
# 2               0          502   42       8  159660.80              3
# 3               0          699   39       1       0.00              2
# 4               1          850   43       2  125510.82              1
#
#    EstimatedSalary  BalanceSalaryRatio  TenureByAge  CreditScoreGivenAge  \
# 0        101348.88            0.000000     0.047619            14.738095
# 1        112542.58            0.744677     0.024390            14.829268
# 2        113931.57            1.401375     0.190476            11.952381
# 3         93826.63            0.000000     0.025641            17.923077
# 4         79084.10            1.587055     0.046512            19.767442
#
#    Num_Trans_12Months  Num_Trans_6Months  Num_Trans_3Months  HasCrCard  \
# ...

# %%
dummy_HasCrCard = pd.get_dummies(data['HasCrCard'], prefix='HasCrCard')
data = pd.concat([data, dummy_HasCrCard], axis=1)
data = data.drop(['HasCrCard','HasCrCard_0'],axis=1)
print(data.head())
# Out:
#    IsActiveMember  CreditScore  Age  Tenure    Balance  NumOfProducts  \
# 0               1          619   42       2       0.00              1
# 1               1          608   41       1   83807.86              1
# 2               0          502   42       8  159660.80              3
# 3               0          699   39       1       0.00              2
# 4               1          850   43       2  125510.82              1
#
#    EstimatedSalary  BalanceSalaryRatio  TenureByAge  CreditScoreGivenAge  \
# 0        101348.88            0.000000     0.047619            14.738095
# 1        112542.58            0.744677     0.024390            14.829268
# 2        113931.57            1.401375     0.190476            11.952381
# 3         93826.63            0.000000     0.025641            17.923077
# 4         79084.10            1.587055     0.046512            19.767442
#
#    Num_Trans_12Months  Num_Trans_6Months  Num_Trans_3Months Geography  Gender  \
# ...

# %%
dummy_Geography = pd.get_dummies(data['Geography'], prefix='Geography')
data = pd.concat([data, dummy_Geography], axis=1)
data = data.drop(['Geography','Geography_Spain'],axis=1)
print(data.head())
# Out:
#    IsActiveMember  CreditScore  Age  Tenure    Balance  NumOfProducts  \
# 0               1          619   42       2       0.00              1
# 1               1          608   41       1   83807.86              1
# 2               0          502   42       8  159660.80              3
# 3               0          699   39       1       0.00              2
# 4               1          850   43       2  125510.82              1
#
#    EstimatedSalary  BalanceSalaryRatio  TenureByAge  CreditScoreGivenAge  \
# 0        101348.88            0.000000     0.047619            14.738095
# 1        112542.58            0.744677     0.024390            14.829268
# 2        113931.57            1.401375     0.190476            11.952381
# 3         93826.63            0.000000     0.025641            17.923077
# 4         79084.10            1.587055     0.046512            19.767442
#
#    Num_Trans_12Months  Num_Trans_6Months  Num_Trans_3Months  Gender  \
# ...

# %%
dummy_Gender = pd.get_dummies(data['Gender'], prefix='Gender')
data = pd.concat([data, dummy_Gender], axis=1)
data = data.drop(['Gender','Gender_Male'],axis=1)
print(data.head())
# Out:
#    IsActiveMember  CreditScore  Age  Tenure    Balance  NumOfProducts  \
# 0               1          619   42       2       0.00              1
# 1               1          608   41       1   83807.86              1
# 2               0          502   42       8  159660.80              3
# 3               0          699   39       1       0.00              2
# 4               1          850   43       2  125510.82              1
#
#    EstimatedSalary  BalanceSalaryRatio  TenureByAge  CreditScoreGivenAge  \
# 0        101348.88            0.000000     0.047619            14.738095
# 1        112542.58            0.744677     0.024390            14.829268
# 2        113931.57            1.401375     0.190476            11.952381
# 3         93826.63            0.000000     0.025641            17.923077
# 4         79084.10            1.587055     0.046512            19.767442
#
#    Num_Trans_12Months  Num_Trans_6Months  Num_Trans_3Months  HasCrCard_1  \
# ...

# %% [markdown]
# # 3. Build the model

# %%
# Load libraries
import pandas as pd
from sklearn.ensemble import RandomForestClassifier # Import Random Forest Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %%
X = data.drop('IsActiveMember',axis=1) # Features
y = data.IsActiveMember # Target variable
print(X.shape)
print(y.shape)
# Out:
# (10000, 16)
# (10000,)

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=1) # 75% training and 25% test

# %%
#Create a Gaussian Classifier
rf_clf=RandomForestClassifier(n_estimators=2,random_state=1)

#Train the model using the training sets
rf_clf.fit(X_train,y_train)

y_pred=rf_clf.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9528

# %% [markdown]
# ### Build Another Forest
# Build another forest. This time with n_estimators = 5 and max_features = "sqrt".

# %%
# Create Decision Tree classifer object
rf_clf2 = RandomForestClassifier(n_estimators=5, max_features="sqrt")

# Train Decision Tree Classifer
rf_clf2.fit(X_train,y_train)

#Predict the response for test dataset
y_pred2 = rf_clf2.predict(X_test)

# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred2))
# Out:
# Accuracy: 0.97

# %%
# Check the confusion matrix of the prediction for the testing set
print(metrics.confusion_matrix(y_test,y_pred2))
# Out:
# [[1144   18]
#  [  57 1281]]

# %% [markdown]
# Great, now accuracy is increased.

# %%
from sklearn.model_selection import GridSearchCV

gs_clf = GridSearchCV(estimator=RandomForestClassifier(random_state=1),
        param_grid={
            'n_estimators':[10,20,50],
            'max_features':['log2','auto','sqrt'],
            'min_samples_leaf':[100,200,300],
        })

gs_clf.fit(X_train,y_train)

# print the best parameters found
print(gs_clf.best_params_)
# Out:
# {'max_features': 'log2', 'min_samples_leaf': 100, 'n_estimators': 50}

# %% [markdown]
# Best model comes up with n_estimators as 50, min_samples_leaf as 100 and max_features as 'log2'.
#
# Let's build this model.

# %%
# Create Decision Tree classifer object
best_clf = RandomForestClassifier(n_estimators=50,min_samples_leaf=100,max_features='log2')

# Train Decision Tree Classifer
best_clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred3 = best_clf.predict(X_test)

# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred3))
# Out:
# Accuracy: 0.9744

# %%
# Check the confusion matrix of the prediction for the testing set
print(metrics.confusion_matrix(y_test,y_pred3))
# Out:
# [[1157    5]
#  [  59 1279]]

# %% [markdown]
# Great, now accuracy is increased to 97.44%.
#
# Let's see the important features of this forest.

# %%
feature_imp = pd.Series(best_clf.feature_importances_,index=X.columns.tolist()).sort_values(ascending=False)
feature_imp
# Out:
# Num_Trans_3Months      0.439492
# Num_Trans_6Months      0.361096
# Num_Trans_12Months     0.182809
# Age                    0.008885
# CreditScoreGivenAge    0.002262
# TenureByAge            0.001227
# CreditScore            0.001220
# EstimatedSalary        0.000799
# Balance                0.000715
# Tenure                 0.000413
# BalanceSalaryRatio     0.000395
# Geography_France       0.000265
# NumOfProducts          0.000201
# Geography_Germany      0.000143
# Gender_Female          0.000061
# HasCrCard_1            0.000018
# dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Creating a bar plot
sns.barplot(x=feature_imp, y=feature_imp.index)
# Add labels to your graph
plt.xlabel('Feature Importance Score')
plt.ylabel('Features')
plt.title("Visualizing Important Features")
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ## Generating the Model on Important Features
#
# Select top 5 features only

# %%
# select only features with relative importance higher than 1%
selected_features = feature_imp[feature_imp>0.003]
print(selected_features)

# create a list from those features: done
selected_list = selected_features.index

# transform both features_train and features_test components to include only selected features
X_train_selected = X_train[selected_list]
X_test_selected = X_test[selected_list]
# Out:
# Num_Trans_3Months     0.439492
# Num_Trans_6Months     0.361096
# Num_Trans_12Months    0.182809
# Age                   0.008885
# dtype: float64

# %%
# Create Decision Tree classifer object
best_clf2 = RandomForestClassifier(n_estimators=50,min_samples_leaf=100,max_features='log2')

# Train Decision Tree Classifer
best_clf2.fit(X_train_selected,y_train)

#Predict the response for test dataset
y_pred4 = best_clf2.predict(X_test_selected)

# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred4))
# Out:
# Accuracy: 0.9748

# %%
# Check the confusion matrix of the prediction for the testing set
print(metrics.confusion_matrix(y_test,y_pred4))
# Out:
# [[1158    4]
#  [  59 1279]]

# %% [markdown]
# This is our final best model as of now.
#
# Let's see how to predict the output for 10 new customers.

# %%
new_customer = X_test_selected.iloc[30:40,:].reset_index(drop=True)
print(new_customer)
# Out:
#    Num_Trans_3Months  Num_Trans_6Months  Num_Trans_12Months  Age
# 0                 11                 71                 167   28
# 1                 86                129                 277   34
# 2                 49                130                 284   37
# 3                 12                 67                 158   55
# 4                 10                117                 203   37
# 5                 22                119                 204   40
# 6                  4                118                 210   45
# 7                 61                101                 161   52
# 8                 50                142                 282   24
# 9                 17                 61                 125   42

# %%
best_clf2.predict(new_customer)
# Out:
# array([0, 1, 1, 0, 0, 0, 0, 1, 1, 0], dtype=int64)

# %% [markdown]
# Here, it is predicting that 6 customers are going to INACTIVE and hence CḤURN.
#
# But what's the probability ? Let's calculate the probability.

# %%
#np.set_printoptions(formatter={'float_kind':'{:f}'.format})

# %%
best_clf2.predict_proba(new_customer).astype('float64')
# Out:
# array([[0.980049, 0.019951],
#        [0.000000, 1.000000],
#        [0.000000, 1.000000],
#        [0.943773, 0.056227],
#        [0.868058, 0.131942],
#        [0.858671, 0.141329],
#        [0.833432, 0.166568],
#        [0.017157, 0.982843],
#        [0.000261, 0.999739],
#        [0.997396, 0.002604]])

# %% [markdown]
# The 1st column denotes the probability of being 0, i.e., INACTIVE(or CHURN). And 2nd column denotes the probability of being 1, i.e., ACTIVE.
#
# We can see that 1st, 4th, 5th, 6th, 7th and 10th customer have highest probability of CHURN, and  all other customers have high probabilities of being ACTIVE.
