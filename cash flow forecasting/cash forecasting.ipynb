# %% [markdown]
# # Time Series
# A time series is a sequence of observations over a certain period.
#
# A univariate time series consists of the values taken by a single variable at periodic time instances over a period, and a multivariate time series consists of the values taken by multiple variables at the same periodic time instances over a period.
#
# The simplest example of a time series that all of us come across on a day to day basis is the change in temperature throughout the day or week or month or year.
#
# The analysis of temporal data is capable of giving us useful insights on how a variable changes over time, or how it depends on the change in the values of other variable(s). This relationship of a variable on its previous values and/or other variables can be analyzed for time series forecasting and has numerous applications in artificial intelligence.

# %% [markdown]
# Time series analysis comprises methods for analyzing time series data in order to extract meaningful statistics and other characteristics of the data. Time series forecasting is the use of a model to predict future values based on previously observed values.

# %% [markdown]
# ### Benefits & Applications of Time Series:
#
# * It helps to achieve various objectives:
#
# * Descriptive Analysis: determines trends and patterns of future using graphs and other tools.
#
# * Forecasting: It is used extensively in financial, business forecasting based on historical trends and patterns
#
# * Explanative Analysis: to study cross-correlation/relationship between two time series and their dependency on one another.
#
# The biggest advantage of using time series analysis – It can be used to understand the past as well as predict the future.

# %% [markdown]
# # Components of Time Series
# Time Series Analysis helps us to recognize the major components in a time series data.
#
# It has four main components:
#
# * **Trend**: Trend is the increase or decrease in the series over a period of time, it persists over a long period of time.
#
# * **Seasonality**: Regular pattern of up and down fluctuations. It is a short-term variation occurring due to seasonal factors.
#
# * **Cyclicity**: It is a medium-term variation caused by circumstances, which repeat in irregular intervals.
#
# * **Irregularity**: It refers to variations which occur due to unpredictable factors and also do not repeat in particular patterns.
#
# <img src = "Images/time1.png">

# %% [markdown]
# ### Types of Trend
# There are many types of trend, for example:
#
# * Linear Trend
# * Damped Trend
# * Exponential Trend
#
# <img src = "Images/time9.png">

# %% [markdown]
# ### Types of Seasonality
# There are many types of seasonality; for example:
#
# * Time of Day
# * Daily
# * Weekly
# * Monthly
# * Yearly
#
# <img src = "Images/time7.png">

# %% [markdown]
# ### Cyclicity and Irregular Component
#
# <img src = "Images/time10.jpg">

# %% [markdown]
# ### Time Series Plot:
#
# A usual time series plot having trend and seasonal components looks like:
# <img src = "Images/time2.png">
#
# Here, you can see that we have data points spread across 4 years and the trend is increasing over time.

# %% [markdown]
# A time series is important in business and policy planning:
#
# * It studies the past behavior of the phenomenon.
#
# * It compares the currenttrends with that in the past or the expected trends.
#
# * It is used in forecasting sales, profit etc. and policy planning by various organizations.
#
# * The cyclic variation help us understand the business cycles.
#
# * The seasonal variation are very useful for businesses and retailers as they earn more in certain seasons.

# %% [markdown]
# # Types of Time Series
# There are two broadly classified types of time series :
# * Stationary Time Series
# * Non-stationary Time Series

# %% [markdown]
# # Stationary Time Series
# There are three basic criterion for a series to be classified as stationary series :
#
# *1*. The mean of the series should not be a function of time rather should be a constant. The image below has the left hand graph satisfying the condition whereas the graph in red has a time dependent mean.
#
# <img src = "Images/time3.png">

# %% [markdown]
# *2*. The variance of the series should not a be a function of time. This property is known as homoscedasticity. Following graph depicts what is and what is not a stationary series. (Notice the varying spread of distribution in the right hand graph)
#
# <img src = "Images/time4.png">

# %% [markdown]
# *3*. The covariance of the i th term and the (i + m) th term should not be a function of time. In the following graph, you will notice the spread becomes closer as the time increases. Hence, the covariance is not constant with time for the ‘red series’.
#
# <img src = "Images/time5.png">

# %% [markdown]
# # Why should a time series be ‘stationary’?
# The reason is that until unless your time series is stationary, you cannot build a time series model.
#
# In cases where the stationary criterion are violated, the first requisite becomes to stationarize the time series and then try stochastic models to predict this time series.
#
# There are multiple ways of bringing this stationarity. Some of them are Detrending, Differencing etc.

# %% [markdown]
# # Python Dates
# A date in Python is not a data type of its own, but we can import a module named datetime to work with dates as date objects.

# %%
# Import the datetime module and display the current date:

import datetime

x = datetime.datetime.now()
print(x)
# Out:
# 2019-09-07 18:46:49.424284

# %% [markdown]
# ### Date Output
# When we execute the code from the example above the result will be:
#
# 2019-09-07 18:16:17.749849

# %% [markdown]
# The date contains year, month, day, hour, minute, second, and microsecond.
#
# The datetime module has many methods to return information about the date object.

# %%
# Return the year and name of weekday:

print(x.year)
print(x.strftime("%A"))
# Out:
# 2019
# Saturday

# %% [markdown]
# ### Creating Date Objects
# To create a date, we can use the datetime() class (constructor) of the datetime module.
#
# The datetime() class requires three parameters to create a date: year, month, day.

# %%
# Create a date object:
x = datetime.datetime(2020, 5, 17)
print(x)
# Out:
# 2020-05-17 00:00:00

# %% [markdown]
# The datetime() class also takes parameters for time and timezone (hour, minute, second, microsecond, tzone), but they are optional, and has a default value of 0, (None for timezone).

# %% [markdown]
# ### The strftime() Method
# The datetime object has a method for formatting date objects into readable strings.
#
# The method is called strftime(), and takes one parameter, format, to specify the format of the returned string:

# %%
# Display the name of the month:
x = datetime.datetime(2019, 9, 8)

# Print the month
print(x.strftime("%B"))

# Print the numeric month
print(x.strftime("%m"))

# Print the day
print(x.strftime("%A"))

# Print the date
print(x.strftime("%d"))
# Out:
# September
# 09
# Sunday
# 08

# %%
# print year
print(x.year)

# print month
print(x.month)

# print day
print(x.day)

# print hour
print(x.hour)
# Out:
# 2019
# 9
# 8
# 0

# %% [markdown]
# # Datetime Format Codes :
#
# <img src = "Images/time11.png">

# %% [markdown]
# # Cash Flow Forecasting:
# ABC Finance Ltd is a finance institution who wants to check for their cash flow in December 2014. They have provided the records with transaction data and an excerpt from CRM with the customer data.
#
# The situation will end on November 2014 and a forecast for the incoming payments in December 2014 is requested.
#
# As an analyst, create a forecasting model to predict the cash flow for ABC Finance Ltd.

# %% [markdown]
# Let's start by reading in the data and examination of the data set.

# %%
#Import the libraries
import pandas as pd
import numpy as np

#Read the Bank Transaction Orders data
data = pd.read_csv('Data/Orders_v02.csv')

# %%
print(data.head())
# Out:
#   OrderID  CustomerID  OrderVolume      ShipMode  Segment   Category  \
# 0   O-109        1011        10.68  Second Class        0  Furniture
# 1   O-110        1025        10.71  Second Class        0  Furniture
# 2   O-111        1029        10.63  Second Class        0  Furniture
# 3   O-112        1006        10.90  Second Class        0  Furniture
# 4   O-113        1015        10.86  Second Class        0  Furniture
#
#    PaymentTerm  Discount  ExistingPurchaseOrder  FirstCustomerOrder  \
# 0           14         5                      1                   1
# 1           14         5                      1                   1
# 2           14         5                      1                   1
# 3           14         5                      1                   1
# 4           14         5                      1                   1
#
#   CashInDate  Month
# 0 2011-01-01      1
# 1 2011-01-02      1
# 2 2011-01-03      1
# 3 2011-01-04      1
# 4 2011-01-05      1

# %%
print(data.tail())
# Out:
#       OrderID  CustomerID  OrderVolume        ShipMode    Segment  \
# 1456  O-46539        1025        60.29  Standard Class  Corporate
# 1457  O-46263        1013        60.00  Standard Class   Consumer
# 1458  O-46921        1016        60.32     First Class  Corporate
# 1459  O-46957        1024        56.95  Standard Class  Corporate
# 1460  O-46359        1017        56.47     First Class  Corporate
#
#              Category  PaymentTerm  Discount ExistingPurchaseOrder  \
# 1456        Furniture           45         3                   Yes
# 1457  Office Supplies           45         0                    No
# 1458  Office Supplies           45         5                    No
# 1459  Office Supplies           45         3                   Yes
# 1460  Office Supplies           45         0                    No
#
#      FirstCustomerOrder  CashInDate
# 1456                 No  27-12-2014
# 1457                 No  28-12-2014
# 1458                 No  29-12-2014
# ...

# %% [markdown]
# Data starts from 1st Jan 2011 and ends at 31st Dec 2014.

# %% [markdown]
# ## CashInDate
# First, We should transform the CashInDate column into the datetime type

# %%
from datetime import datetime, date
print(data.CashInDate[:10])
data.CashInDate = pd.to_datetime(data.CashInDate, format="%d-%m-%Y")
print(data.CashInDate[:10])
# Out:
# 0    01-01-2011
# 1    02-01-2011
# 2    03-01-2011
# 3    04-01-2011
# 4    05-01-2011
# 5    06-01-2011
# 6    07-01-2011
# 7    08-01-2011
# 8    09-01-2011
# 9    10-01-2011
# Name: CashInDate, dtype: object
# 0   2011-01-01
# 1   2011-01-02
# 2   2011-01-03
# 3   2011-01-04
# 4   2011-01-05
# 5   2011-01-06
# 6   2011-01-07
# 7   2011-01-08
# 8   2011-01-09
# 9   2011-01-10
# Name: CashInDate, dtype: datetime64[ns]

# %% [markdown]
# ### Code Explanation
# * In Step 1, We import datetime and date functions from datetime package.
#
# * In Step 2, we are printing first 10 CashInDate to check how these dates are stored.
#
# * In Step 3, we are converting CashInDate from object type to datetime type by using pandas' to_datetime function which takes the column CashInDate and format in which date is stored.
#
# * In step 4, we are printing first 10 CashInDate to check how these dates are represented now.

# %% [markdown]
# Do we have missing data?

# %%
#Missing Values
print(data.shape)
data.isnull().sum()
# Out:
# (1461, 11)
# OrderID                  0
# CustomerID               0
# OrderVolume              0
# ShipMode                 0
# Segment                  0
# Category                 0
# PaymentTerm              0
# Discount                 0
# ExistingPurchaseOrder    0
# FirstCustomerOrder       0
# CashInDate               0
# dtype: int64

# %% [markdown]
# No missing values

# %% [markdown]
# ## Discount
# Now let's look at the Discount column. Which values does this include?

# %%
data.Discount.value_counts()
# Out:
# 0    612
# 5    459
# 3    390
# Name: Discount, dtype: int64

# %% [markdown]
# ## Segment
# Let's continue the investigation. What values does the Segment column have?

# %%
data.Segment.value_counts()
# Out:
# Corporate    1181
# Consumer      280
# Name: Segment, dtype: int64

# %% [markdown]
# These are categorical data with two possible outputs. Replace this with 1 and 0.

# %%
#Convert it to 0 for Consumer and 1 for Corporate
data.Segment.replace(('Corporate', 'Consumer'), (1, 0), inplace=True)

# %% [markdown]
# ## ExistingPurchaseOrder
# Is there a sales order? Replace 'yes' with 1 and 'no' with 0.

# %%
#replaced 'Yes' and 'No' with 1 and 0
data.ExistingPurchaseOrder.replace(('Yes', 'No'), (1, 0), inplace=True)

# %% [markdown]
# ## FirstCustomerOrder
# And again, 'yes' replaced by 1 and 'no' by 0.

# %%
#Same game: replaced 'Yes' and 'No' with 1 and 0
data.FirstCustomerOrder.replace(('Yes', 'No'), (1, 0), inplace=True)

# %% [markdown]
# ## DaysBetween
# Define now our target column. The number of days between the invoice date and the receipt of the payment

# %%
#Define the new column with the month of Cash In:
data['Month'] = data.CashInDate.dt.month
print(data['Month'].value_counts())
# Out:
# 12    124
# 10    124
# 8     124
# 7     124
# 5     124
# 3     124
# 1     124
# 11    120
# 9     120
# 6     120
# 4     120
# 2     113
# Name: Month, dtype: int64

# %% [markdown]
# ## MaxFlow and MinFlow
# December has maximum flow and March has least

# %%
print(data.ShipMode.value_counts())
print(data.Category.value_counts())
# Out:
# Standard Class    840
# Second Class      329
# First Class       217
# Same Day           75
# Name: ShipMode, dtype: int64
# Office Supplies    1265
# Furniture           134
# Technology           62
# Name: Category, dtype: int64

# %% [markdown]
# ## ShipMode and Category
# These columns contain categorical data with multiple possibilities. I will do this later with the help of hot-one-coding.

# %% [markdown]
# ## OrderID
# This column does not contribute to the model and will be removed later

# %% [markdown]
# ## Customer
# Contains the information as CustomerID in terms of this use case. I remove these too.

# %%
ts_data = data[['CashInDate','OrderVolume']]
ts_data = ts_data.set_index('CashInDate')
print(ts_data.shape)
print(ts_data.head())
# Out:
# (1461, 1)
#             OrderVolume
# CashInDate
# 2011-01-01        10.68
# 2011-01-02        10.71
# 2011-01-03        10.63
# 2011-01-04        10.90
# 2011-01-05        10.86

# %% [markdown]
# ### Code Explanation
# * Step 1 : Select only CashInDate and OrderVolume as variables
# * Step 2 : Convert CashInDate into DatetimeIndex using set_index(). This is used to do for plotting time series efficiently.

# %%
print(ts_data['2014'])
print(ts_data['2014-01'])
ts2014 = ts_data['2014']
# Out:
#             OrderVolume
# CashInDate
# 2014-01-01        36.91
# 2014-01-02        36.26
# 2014-01-03        36.32
# 2014-01-04        36.05
# 2014-01-05        35.48
# ...                 ...
# 2014-12-27        60.29
# 2014-12-28        60.00
# 2014-12-29        60.32
# 2014-12-30        56.95
# 2014-12-31        56.47
#
# [365 rows x 1 columns]
#             OrderVolume
# CashInDate
# 2014-01-01        36.91
# 2014-01-02        36.26
# 2014-01-03        36.32
# 2014-01-04        36.05
# 2014-01-05        35.48
# 2014-01-06        33.97
# 2014-01-07        34.62
# 2014-01-08        35.25
# 2014-01-09        35.03
# 2014-01-10        34.87
# 2014-01-11        36.19
# 2014-01-12        36.70
# 2014-01-13        37.26
# 2014-01-14        37.71
# 2014-01-15        37.59
# 2014-01-16        36.57
# 2014-01-17        35.85
# 2014-01-18        35.62
# 2014-01-19        34.74
# 2014-01-20        35.79
# 2014-01-21        36.22
# 2014-01-22        36.33
# 2014-01-23        37.10
# ...

# %% [markdown]
# ### Code Explanation
#
# Now, we can do slicing of the time series using Year, month, etc. by using year and month value as index.

# %% [markdown]
# As seen from the previous statements, we are given 4 years of data(2011-2014) at daily level with the OrderVolume as Cash Flow and we need to estimate the OrderVolume as Cash Flow for future.
#
# We will create the train and test file for modeling.
#
# The first 3 years (Jan 2011 – Dec 2013) are used as training data and next 1 year (Jan 2014 – Dec 2014) as testing data.

# %%
#Creating train and test set 
#Index 1096 marks the end of Decemebr 2013 
train=ts_data[0:1096] 
test=ts_data[1096:]

# %%
# check train's last few rows and test's first few rows to confirm non-overlapping of date and values
print(train.tail())
print(test.head())
# Out:
#             OrderVolume
# CashInDate
# 2013-12-27        35.18
# 2013-12-28        33.69
# 2013-12-29        36.28
# 2013-12-30        36.65
# 2013-12-31        37.44
#             OrderVolume
# CashInDate
# 2014-01-01        36.91
# 2014-01-02        36.26
# 2014-01-03        36.32
# 2014-01-04        36.05
# 2014-01-05        35.48

# %% [markdown]
# ### Import all the required libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
# %matplotlib inline

# %% [markdown]
# Let’s visualize the data (train and test together) to know how it varies over a time period.

# %%
#Plotting data
train['OrderVolume'].plot(figsize=(15,8), title= 'Order Volume', fontsize=14,color='green')
test['OrderVolume'].plot(figsize=(15,8), title= 'Order Volume', fontsize=14,color='red')
plt.show()

# %% [markdown]
# # Time Series Forecasting Methods
#
# Let's go through different approaches/methods to forecast time series :
#
# * Naive Approach
#
# * Simple Average
#
# * Moving Average
#
# * Single Exponential Smoothing
#
# * Hold's Linear Trend Method
#
# * Holt's Winter Seasonal Method
#
# * ARIMA

# %% [markdown]
# # Method 1: Naive Approach
# Many a times we are provided with a time series, which is stable throughout it’s time period.
#
# If we want to forecast the time series for the next day, we can simply take the last day value and estimate the same value for the next day.
#
# Such forecasting technique which assumes that the next expected point is equal to the last observed point is called **Naive Method**.
#
# <img src = "Images/time12.png">

# %% [markdown]
# Now we will implement the **Naive method** to forecast the OrderVolume for test data.

# %%
dd = np.asarray(train.OrderVolume)
y_hat = test.copy()
y_hat['naive'] = dd[len(dd)-1]

# %% [markdown]
# ### Code Explanation :
# * Step 1 : Convert the train data into an array called as dd.
# * Step 2 : Take predicted values as test values(naive method)
# * Step 3 : Copy these values in y_hat

# %% [markdown]
# Let's make a plot of train values, test values and predicted values using naive method.

# %%
plt.figure(figsize=(12,8))
plt.plot(train.index, train['OrderVolume'], label='Train',color='green')
plt.plot(test.index,test['OrderVolume'], label='Test',color='red')
plt.plot(y_hat.index,y_hat['naive'], label='Naive Forecast')
plt.legend(loc='best')
plt.title("Naive Forecast")
plt.show()

# %% [markdown]
# We will now calculate RMSE to check to accuracy of our model on test data set.

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
rms = sqrt(mean_squared_error(test.OrderVolume, y_hat.naive))
print(rms)
# Out:
# 10.963107985983209

# %% [markdown]
# We can infer from the RMSE value and the graph above, that Naive method isn’t suited for datasets with high variability.
#
# It is best suited for stable datasets. We can still improve our score by adopting different techniques.
#
# Now we will look at another technique and try to improve our score.

# %% [markdown]
# # Method 2: – Simple Average
#
# Many a times we are provided with a dataset, which though varies by a small margin throughout it’s time period, but the average at each time period remains constant. In such a case we can forecast the time series of the next day somewhere similar to the average of all the past days.
#
# Such forecasting technique which forecasts the expected value equal to the average of all previously observed points is called **Simple Average** technique.
#
# <img src = "Images/time13.png">

# %% [markdown]
# We take all the values previously known, calculate the average and take it as the next value.
#
# As a forecasting method, there are actually situations where this technique works the best.

# %%
y_hat_avg = test.copy()
y_hat_avg['avg_forecast'] = train['OrderVolume'].mean()

# %% [markdown]
# Let's make a plot of train values, test values and predicted values using simple average method.

# %%
plt.figure(figsize=(12,8))
plt.plot(train['OrderVolume'], label='Train',color='green')
plt.plot(test['OrderVolume'], label='Test',color='red')
plt.plot(y_hat_avg['avg_forecast'], label='Average Forecast')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# We will now calculate RMSE to check to accuracy of our model.

# %%
rms = sqrt(mean_squared_error(test.OrderVolume, y_hat_avg.avg_forecast))
print(rms)
# Out:
# 28.32226413250275

# %% [markdown]
# We can see that this model didn’t improve our score.
#
# Hence we can infer from the score that this method works best when the average at each time period remains constant.
#
# Though the score of Naive method is better than Average method, but this does not mean that the Naive method is better than Average method on all datasets.
#
# We should move step by step to each model and confirm whether it improves our model or not.

# %% [markdown]
# # Method 3 – Moving Average
#
# Many a times we are provided with a dataset, in which the time series increases/decreases sharply some time periods ago.
#
# In previous Average method, we used the mean of all the previous data, but using all the previous data doesn’t sound right.
#
# Using the prices of the initial period would highly affect the forecast for the next period.
#
# Therefore as an improvement over simple average, we will take the average of the prices for last few time periods only.
#
# Obviously the thinking here is that only the recent values matter.
#
# Such forecasting technique which uses window of time period for calculating the average is called **Moving Average** technique. Calculation of the moving average involves what is sometimes called a **sliding window** of size n.
#
# Using a simple moving average model, we forecast the next value(s) in a time series based on the average of a fixed finite number *p* of the previous values. Thus, for all i > p :
#
# <img src = "Images/time14.png">

# %% [markdown]
# A moving average can actually be quite effective, especially if you pick the right p for the series.
#
# **.rolling(period)** takes a moving average of the time series values.

# %%
y_hat_avg = test.copy()
y_hat_avg['moving_avg_forecast'] = train['OrderVolume'].rolling(60).mean().iloc[-1]

# %% [markdown]
# Let's make a plot of train values, test values and predicted values using moving average method.

# %%
plt.figure(figsize=(16,8))
plt.plot(train['OrderVolume'], label='Train',color='green')
plt.plot(test['OrderVolume'], label='Test',color='red')
plt.plot(y_hat_avg['moving_avg_forecast'], label='Moving Average Forecast')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# We will now calculate RMSE to check to accuracy of our model on test data set.

# %%
rms = sqrt(mean_squared_error(test.OrderVolume, y_hat_avg.moving_avg_forecast))
print(rms)
# Out:
# 14.382306946717197

# %% [markdown]
# We can see that **Naive method** outperforms both **Average method** and **Moving Average method** for this dataset.
#
# An advancement over Moving average method is **Weighted moving average** method.
#
# In the Moving average method as seen above, we equally weigh the past *n* observations. But we might encounter situations where each of the observation from the past n impacts the forecast in a different way.
#
# Such a technique which weighs the past observations differently is called **Weighted Moving Average** technique.
#
# A weighted moving average is a moving average where within the *sliding window* values are given different weights, typically so that more recent points matter more.
#
# <img src = "time15.png">

# %% [markdown]
# Now we will look at Simple Exponential Smoothing method and see how it performs.

# %% [markdown]
# # Method 4 – Simple Exponential Smoothing
# After we have understood the above methods, we can note that both Simple average and Weighted moving average lie on completely opposite ends.
#
# We would need something between these two extremes approaches which takes into account all the data while weighing the data points differently.
#
# For example it may be sensible to attach larger weights to more recent observations than to observations from the distant past.
#
# The technique which works on this principle is called **Simple exponential smoothing**.
#
# Forecasts are calculated using weighted averages where the weights decrease exponentially as observations come from further in the past, the smallest weights are associated with the oldest observations:
#
# <img src = "Images/time16.png">

# %% [markdown]
# where 0≤ α ≤1 is the smoothing parameter.
#
# The one-step-ahead forecast for time T+1 is a weighted average of all the observations in the series y1,…,yT. The rate at which the weights decrease is controlled by the parameter α.
#
# If you stare at it just long enough, you will see that the expected value $ŷ_{x}$ is the sum of two products: α⋅$y_{t}$ and (1−α)⋅$ŷ_{t-1}$.
#
# Hence, it can also be written as :
#
# <img src = "Images/time17.png">

# %% [markdown]
# So essentially we’ve got a weighted moving average with two weights: α and 1−α.
#
# As we can see, 1−α is multiplied by the previous expected value $ŷ_{x−1}$ which makes the expression recursive. And this is why this method is called **Exponential**.
#
# The forecast at time t+1 is equal to a weighted average between the most recent observation $y_{t}$ and the most recent forecast $ŷ_{t|t−1}$.

# %%
from statsmodels.tsa.api import ExponentialSmoothing, SimpleExpSmoothing, Holt

y_hat_avg = test.copy()
fit2 = SimpleExpSmoothing(np.asarray(train['OrderVolume'])).fit(smoothing_level=0.6,optimized=False)
y_hat_avg['SES'] = fit2.forecast(len(test))

# %% [markdown]
# For Smoothing and holt's methods, we will make use of statsmodels' tsa module and import ExponentialSmoothing, SimpleExpSmoothing, and Holt functions
#
# smoothing_level in SimpleExpSmoothing signifies the value of alpha parameter.

# %% [markdown]
# Let's make a plot of train values, test values and predicted values using simple exponential smooething method.

# %%
plt.figure(figsize=(16,8))
plt.plot(train['OrderVolume'], label='Train',color='green')
plt.plot(test['OrderVolume'], label='Test',color='red')
plt.plot(y_hat_avg['SES'], label='SES')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# We will now calculate RMSE to check to accuracy of our model.

# %%
rms = sqrt(mean_squared_error(test.OrderVolume, y_hat_avg.SES))
print(rms)
# Out:
# 11.352341906841549

# %% [markdown]
# We can see that implementing Simple exponential model with alpha as 0.6 generates a better model than other average methods. We can tune the parameter using the validation set to generate even a better Simple exponential model.

# %% [markdown]
# # Method 5 – Holt’s Linear Trend method
# We have now learnt several methods to forecast but we can see that these models don’t work well on data with high variations. Consider that the time series of the data is increasing.
#
# If we use any of the above methods, it won’t take into account this trend.

# %% [markdown]
# Trend is the general pattern of prices that we observe over a period of time. In our case we can see that there is an increasing trend.
#
# Although each one of these methods can be applied to the trend as well.

# %% [markdown]
# E.g. the Naive method would assume that trend between last two points is going to stay the same, or we could average all slopes between all points to get an average trend, use a moving trend average or apply exponential smoothing.
#
# But we need a method that can map the trend accurately without any assumptions. Such a method that takes into account the trend of the dataset is called **Holt’s Linear Trend method**.

# %% [markdown]
# Each Time series dataset can be decomposed into it’s componenets which are Trend, Seasonality and Residual. Any dataset that follows a trend can use Holt’s linear trend method for forecasting.

# %% [markdown]
# statsmodels' sm module provides seasonal_decompose function which is a very good function to decompose a time series into trend, seasonality and irregular component.

# %%
import statsmodels.api as sm
sm.tsa.seasonal_decompose(train.OrderVolume).plot()
plt.show()

# %% [markdown]
# We can see from the graphs obtained that this dataset follows an increasing trend. Hence we can use Holt’s linear trend to forecast the future prices.
#
# Holt extended simple exponential smoothing to allow forecasting of data with a trend. It is nothing more than exponential smoothing applied to both level(the average value in the series) and trend.
#
# To express this in mathematical notation we now need three equations: one for level, one for the trend and one to combine the level and trend to get the expected forecast ŷ.
#
# <img src = "Images/time18.png">

# %% [markdown]
# The values we predicted in the above algorithms are called **Level**. In the above three equations, you can notice that we have added level and trend to generate the forecast equation.
#
# As with simple exponential smoothing, the level equation here shows that it is a weighted average of observation and the within-sample one-step-ahead forecast.
#
# The trend equation shows that it is a weighted average of the estimated trend at time t based on ℓ(t)−ℓ(t−1) and b(t−1), the previous estimate of the trend.
#
# We will add these equations to generate Forecast equation.
#
# We can also generate a multiplicative forecast equation by multiplying trend and level instead of adding it. W
#
# hen the trend increases or decreases linearly, additive equation is used whereas when the trend increases of decreases exponentially, multiplicative equation is used.
#
# Practice shows that multiplicative is a more stable predictor, the additive method however is simpler to understand.
#
# <img src = "Images/time19.png">

# %%
y_hat_avg = test.copy()

fit1 = Holt(np.asarray(train['OrderVolume'])).fit(smoothing_level = 0.3,smoothing_slope = 0.1)
y_hat_avg['Holt_linear'] = fit1.forecast(len(test))

# %% [markdown]
# Let's make a plot of train values, test values and predicted values using Holt's Linear Trend method.

# %%
plt.figure(figsize=(16,8))
plt.plot(train['OrderVolume'], label='Train',color='green')
plt.plot(test['OrderVolume'], label='Test',color='red')
plt.plot(y_hat_avg['Holt_linear'], label='Holt_linear')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# We will now calculate RMSE to check to accuracy of our model.

# %%
rms = sqrt(mean_squared_error(test.OrderVolume, y_hat_avg.Holt_linear))
print(rms)
# Out:
# 12.123128174014505

# %% [markdown]
# # Method 6 – Holt-Winters Method
# So let’s introduce a new term which will be used in this algorithm.
#
# Datasets which show a similar set of pattern after fixed intervals of a time period suffer from seasonality.

# %% [markdown]
# The above mentioned models don’t take into account the seasonality of the dataset while forecasting. Hence we need a method that takes into account both trend and seasonality to forecast future prices. One such algorithm that we can use in such a scenario is **Holt’s Winter method**. The idea behind triple exponential smoothing(Holt’s Winter) is to apply exponential smoothing to the seasonal components in addition to level and trend.
#
# Using Holt’s winter method will be the best option among the rest of the models beacuse of the seasonality factor. The Holt-Winters seasonal method comprises the forecast equation and three smoothing equations — one for the level ℓt, one for trend bt and one for the seasonal component denoted by st, with smoothing parameters α, β and γ.

# %% [markdown]
# <img src = "Images/time20.png">
#
# where s is the length of the seasonal cycle, for 0 ≤ α ≤ 1, 0 ≤ β ≤ 1 and 0 ≤ γ ≤ 1.

# %% [markdown]
# The level equation shows a weighted average between the seasonally adjusted observation and the non-seasonal forecast for time t. The trend equation is identical to Holt’s linear method. The seasonal equation shows a weighted average between the current seasonal index, and the seasonal index of the same season last year (i.e., s time periods ago).
#
# In this method also, we can implement both additive and multiplicative technique.  The additive method is preferred when the seasonal variations are roughly constant through the series, while the multiplicative method is preferred when the seasonal variations are changing proportional to the level of the series.

# %%
y_hat_avg = test.copy()
fit1 = ExponentialSmoothing(np.asarray(train['OrderVolume']) ,seasonal_periods=7,trend='add', seasonal=None).fit()
y_hat_avg['Holt_Winter'] = fit1.forecast(len(test))

# %% [markdown]
# Let's make a plot of train values, test values and predicted values using Holt's Winter method.

# %%
plt.figure(figsize=(16,8))
plt.plot(train['OrderVolume'], label='Train',color='green')
plt.plot(test['OrderVolume'], label='Test',color='red')
plt.plot(y_hat_avg['Holt_Winter'], label='Holt_Winter')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# We will now calculate RMSE to check to accuracy of our model.

# %%
rms = sqrt(mean_squared_error(test.OrderVolume, y_hat_avg.Holt_Winter))
print(rms)
# Out:
# 6.0813957604959805

# %% [markdown]
# We can see from the graph that mapping correct trend and seasonality provides a far better solution.
#
# Other parameters can be tuned as per the dataset. I have used default parameters while building this model. You can tune the parameters to achieve a better model.

# %% [markdown]
# # Method 7 – ARIMA
# Another common Time series model that is very popular among the Data scientists is **ARIMA**.
#
# It stand for **AutoRegressive Integrated Moving Average**.
#
# While exponential smoothing models were based on a description of trend and seasonality in the data, ARIMA models aim to describe the correlations in the data with each other.

# %% [markdown]
# To use ARIMA, we need to first ensure that the data is stationary (time, variance, co-variance should not be dependent on time).

# %% [markdown]
# ### What is stationary process?
#
# Stationarity is defined using very strict criterion. However, for practical purposes we can assume the series to be stationary if it has constant statistical properties over time, ie. the following:
#
# * Constant mean
# * Constant variance
# * An autocovariance that does not depend on time.
#
# <img src = "Images/time21.png">

# %% [markdown]
# # Methods to Check Stationarity
# The next step is to determine whether a given series is stationary or not and deal with it accordingly.
#
# * Visual test
#
# * Statistical Test

# %% [markdown]
# ## Visual Test
# Consider the plots we used in the previous section. We were able to identify the series in which mean and variance were changing with time, simply by looking at each plot. Similarly, we can plot the data and determine if the properties of the series are changing with time or not.

# %%
plt.figure(figsize=(16,8))
plt.plot(train['OrderVolume'], label='Train',color='green')
plt.plot(test['OrderVolume'], label='Test',color='red')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# Although its very clear that we have a trend (varying mean) in the above series, this visual approach might not always give accurate results.
#
# It is better to confirm the observations using some statistical tests.

# %% [markdown]
# ## Statistical test
# Instead of going for the visual test, we can use statistical tests like the **ADF stationary tests**.
#
# The test indicates that the statistical properties of a given series are not constant with time, which is the condition for stationary time series.

# %% [markdown]
# ## ADF (Augmented Dickey Fuller) Test
#
# The null and alternate hypothesis of this test are:
#
# * **Null Hypothesis**: The series is non-stationary.
#
# * **Alternate Hypothesis**: The series is stationary.
#
# The test results comprise of a Test Statistic and some Critical Values for difference confidence levels.
#
# * If the **Test Statistic** is less than the **Critical Value** : We can reject the null hypothesis and say that the series is stationary.
#
# * If the **Test Statistic** is greater than the **Critical Value** : We fail to reject the null hypothesis and say that the series is non-stationary.
#
# We can also interpret the result using the p-value from the test.
#
# * **p-value > 0.05**: Fail to reject the null hypothesis, the time series is non-stationary.
#
# * **p-value <= 0.05**: Reject the null hypothesis, the time series is stationary.
#
# This means that the series can be linear or difference stationary.

# %%
from statsmodels.tsa.stattools import adfuller

#Perform Dickey-Fuller test:
dftest = adfuller(ts_data.OrderVolume, autolag='AIC')
print("Test Statistic : ",dftest[0])
print("p-value : ",dftest[1])
print("Critical Values : ",dftest[4])
# Out:
# Test Statistic :  0.5134637958978374
# p-value :  0.9852766233353208
# Critical Values :  {'1%': -3.4348554210983093, '5%': -2.8635298424390276, '10%': -2.5678293754552732}

# %% [markdown]
# ADF test can be done by using adfuller() which takes time series to check for stationarity and autolag which is 'AIC'.

# %% [markdown]
# ### Results of ADF test:
#
# The ADF tests gives the following results –
# * test statistic
# * p value
# * critical value at 1% confidence interval
# * critical value at 5% confidence interval
# * critical value at 10% confidence interval
#
# The results of our test for this particular series are:
# * p-value > 0.05 : Therefore, fail to reject null hypothesis
# * Test-statistic(-0.054) > Critical Value 10%(-2.568) : Therefore, fail to reject null hypothesis
#
# Therefore, the time series is **non-stationary**.

# %% [markdown]
# # Types of Stationarity
# Let us understand the different types of stationarities and how to interpret the results of the above tests.
#
# * **Trend Stationary**: A series that exhibits a trend is referred to as a trend stationary series. Once the trend is removed, the resulting series will be strict stationary.
#
# * **Difference Stationary**: A time series that shows stationarity after differencing falls under difference stationary.
#
# * **Strict Stationary** : A tiime series that is neither trend stationary nor difference stationary falls under strict stationary.

# %% [markdown]
# # Making a Time Series Stationary
# Now that we are familiar with the concept of stationarity and its different types, we can finally move on to actually making our series stationary.
#
# Always keep in mind that in order to use time series forecasting models, it is necessary to convert any non-stationary series to a stationary series first.

# %% [markdown]
# ## Differencing
# Differencing is a method of transforming a time series dataset.
#
# In this method, we compute the difference of consecutive terms in the series.
#
# It can be used to remove the series dependence on time, so-called temporal dependence.
#
# This includes structures like trends and seasonality.

# %% [markdown]
# Differencing is performed by subtracting the previous observation from the current observation.
#
#
# ** difference(t) = observation(t) - observation(t-1) **

# %% [markdown]
# Inverting the differencing process is required when a prediction must be converted back into the original scale.
#
# This process can be reversed by adding the observation at the prior time step to the difference value.
#
# ** inverted(t) = differenced(t) + observation(t-1) **

# %% [markdown]
# ## Lag Difference
# Taking the difference between consecutive observations is called a lag-1 difference.
#
# The lag difference can be adjusted to suit the specific temporal structure.
#
# For time series with a seasonal component, the lag may be expected to be the period (width) of the seasonality.

# %% [markdown]
# ## Difference Order
# Some temporal structure may still exist after performing a differencing operation, such as in the case of a nonlinear trend.
#
# As such, the process of differencing can be repeated more than once until all temporal dependence has been removed.
#
# The number of times that differencing is performed is called the difference order.

# %% [markdown]
# ## diff()
# The Pandas library provides a function to automatically calculate the difference of a dataset.
#
# This diff() function is provided on both the Series and DataFrame objects.
#
# After differencing, we get first value as NA value, which we need to drop using .dropna() method.

# %%
diff = ts_data['OrderVolume'].diff()
plt.plot(diff)
plt.show()

diff = diff.dropna()

dftest = adfuller(diff, autolag='AIC')
print("Test Statistic : ",dftest[0])
print("p-value : ",dftest[1])
print("Critical Values : ",dftest[4])
# Out:
# Test Statistic :  -16.08745410993648
# p-value :  5.297474356793416e-29
# Critical Values :  {'1%': -3.4348554210983093, '5%': -2.8635298424390276, '10%': -2.5678293754552732}

# %% [markdown]
# ADF test can be done by using adfuller() which takes time series to check for stationarity and autolag which is 'AIC'.

# %% [markdown]
# ### Results of ADF test:
#
# The results of our test for this differenced series are:
# * p-value < 0.05 : Therefore, we can reject null hypothesis
# * Test-statistic(-16.087) < Critical Value 1%(-3.4348) : Therefore, we can reject null hypothesis
#
# Since test statistic is lower than 1% critical value, it means that we are 99% sure that we have a stationary series.
# Therefore, the time series is **stationary**.

# %% [markdown]
# ### Autoregressive Integrated Moving Average Model
# An ARIMA model is a class of statistical models for analyzing and forecasting time series data.
#
# ### AR: Autoregression.
# A model that uses the dependent relationship between an observation and some number of lagged observations.
#
# ### I: Integrated.
# The use of differencing of raw observations (e.g. subtracting an observation from an observation at the previous time step) in order to make the time series stationary.
#
# ### MA: Moving Average.
# A model that uses the dependency between an observation and a residual error from a moving average model applied to lagged observations.
#
# Each of these components are explicitly specified in the model as a parameter. A standard notation is used of ARIMA(p,d,q) where the parameters are substituted with integer values to quickly indicate the specific ARIMA model being used.

# %% [markdown]
# The parameters of the ARIMA model are defined as follows:
#
# * **p**: The number of lag observations included in the model, also called the lag order.
# * **d**: The number of times that the raw observations are differenced, also called the degree of differencing.
# * **q**: The size of the moving average window, also called the order of moving average.
#
# A linear regression model is constructed including the specified number and type of terms, and the data is prepared by a degree of differencing in order to make it stationary, i.e. to remove trend and seasonal structures that negatively affect the regression model.
#
# A value of 0 can be used for a parameter, which indicates to not use that element of the model.
#
# This way, the ARIMA model can be configured to perform the function of an ARMA model, and even a simple AR, I, or MA model.

# %%
#ACF and PACF plots:
from statsmodels.tsa.stattools import acf, pacf

lag_acf = acf(diff, nlags=7)
lag_pacf = pacf(diff, nlags=7, method='ols')
# Out:
# C:\Users\ab275\Anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:541: FutureWarning: fft=True will become the default in a future version of statsmodels. To suppress this warning, explicitly set fft=False.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ACF and PACF values are calculated using statsmodels' tsa module and acf and pacf functions which takes time series data and number of lags.

# %%
#Plot ACF: 
plt.subplot(121) 
plt.plot(lag_acf)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(diff)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(diff)),linestyle='--',color='gray')
plt.title('Autocorrelation Function')

#Plot PACF:
plt.subplot(122)
plt.plot(lag_pacf)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(diff)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(diff)),linestyle='--',color='gray')
plt.title('Partial Autocorrelation Function')
# Out:
# Text(0.5,1,'Partial Autocorrelation Function')

# %% [markdown]
# While plotting ACF and PACF, we need to plot confidence intervals as dashed lines as well. This is done to check at which points these acf and pacf values have started becoming significant.

# %% [markdown]
# ### How to determin p, d, q
# It's easy to determine I. In our case, we see the first order differencing make the ts stationary. Therefore, I = 1.
#
# AR model might be investigated first with lag length selected from the PACF or via empirical investigation. In our case, it's clearly that within 2 lags the AR is significant. Which means, we can use AR = 2, or p = 2
#
# MA model might be investigated first with lag length selected from the ACF or via empirical investigation. In our case, it's clearly that within 2 lags the MA is significant. Which means, we can use MA = 2 or q = 2

# %% [markdown]
# p = 2, d = 1, q = 2
#
# Now AR, MA & ARIMA models for the data

# %%
from statsmodels.tsa.arima_model import ARIMA

# %% [markdown]
# For different AR, MA and ARMA models, we will make use of ARIMA method provided by statsmodels' tsa module.
#
# ARIMA function takes time series to model and order which are values of (p,d,q)
#
# p != 0 --> AR exists
# q != 0 --> MA exists
# d != 0 --> Differencing exists
#
# Different values of p,d,q denotes the order of AR, differencing and MA.
#
# After building a model, .fit() method is used to train the model.
#
# The model will also provide .fiitedvalues for the predicted values for training data.

# %% [markdown]
# ### AR model (1,1,0)

# %%
model = ARIMA(diff, order=(1, 1, 0))  
results_AR = model.fit(disp=-1)  
plt.plot(diff)
plt.plot(results_AR.fittedvalues, color='red')
plt.title('AR Model')
# Out:
# C:\Users\ab275\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\ab275\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# Text(0.5,1,'AR Model')

# %% [markdown]
# ## MA model (0,1,1)

# %%
# MA model
model = ARIMA(diff, order=(0, 1, 1))  
results_MA = model.fit(disp=-1)  
plt.plot(diff)
plt.plot(results_MA.fittedvalues, color='red')
plt.title('MA model')
# Out:
# C:\Users\ab275\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\ab275\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# Text(0.5,1,'MA model')

# %% [markdown]
# ## ARIMA model (1,1,1)

# %%
# ARIMA model
model = ARIMA(diff, order=(1, 1, 1))  
results_ARIMA = model.fit(disp=0)  
plt.plot(diff)
plt.plot(results_ARIMA.fittedvalues, color='red')
plt.title('ARIMA model')
# Out:
# C:\Users\ab275\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\ab275\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# Text(0.5,1,'ARIMA model')

# %% [markdown]
# # Taking it back to the original scale
# Lets scale it back to the original values and see how well it performs there. First step would be to store the predicted results as a separate series and observe it.

# %%
preds = pd.Series(results_ARIMA.fittedvalues, copy = True)
preds[0] = train['OrderVolume'][0]
preds_cumsum = preds.cumsum()

print(preds_cumsum.head())
print(preds_cumsum.tail())
# Out:
# CashInDate
# 2011-01-03    10.680000
# 2011-01-04    10.733882
# 2011-01-05    10.542630
# 2011-01-06    10.625377
# 2011-01-07    10.122223
# dtype: float64
# CashInDate
# 2014-12-27     9.177629
# 2014-12-28     7.345229
# 2014-12-29     7.694537
# 2014-12-30     7.447216
# 2014-12-31    10.808047
# dtype: float64

# %%
diff_cumsum = diff
diff_cumsum[0] = train['OrderVolume'][0]
diff_cumsum = diff_cumsum.cumsum()

plt.plot(diff_cumsum,color='green')
plt.plot(preds_cumsum,color='red')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# # auto_arima()
#
# To build the model for different values of p,d,q together, pyramid_arima library provides auto_arima function which will do so and provide AIC for the predicted values.
#
# The next step should be just to choose those values for which AIC is least.

# %%
#building the model
from pyramid.arima import auto_arima
model = auto_arima(train, trace=True, error_action='ignore', suppress_warnings=True)
#model.fit(train)
# Out:
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(0, 0, 0, 1); AIC=1555.625, BIC=1585.616, Fit time=1.326 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 0, 0, 1); AIC=1558.197, BIC=1568.194, Fit time=0.079 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(0, 0, 0, 1); AIC=1560.170, BIC=1575.165, Fit time=0.067 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 0, 0, 1); AIC=1560.168, BIC=1575.164, Fit time=0.082 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 0, 0, 1); AIC=1563.430, BIC=1588.422, Fit time=0.404 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(0, 0, 0, 1); AIC=1557.171, BIC=1592.160, Fit time=1.409 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(0, 0, 0, 1); AIC=1563.334, BIC=1588.327, Fit time=0.462 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(0, 0, 0, 1); AIC=1556.912, BIC=1591.901, Fit time=1.224 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 0, 0, 1); AIC=1562.052, BIC=1582.046, Fit time=0.424 seconds
# ...

# %% [markdown]
# The best model with least AIC(1555) is first model with parameters (2,1,2).

# %%
model.fit(train)
# Out:
# ARIMA(callback=None, disp=0, maxiter=50, method=None, order=(2, 1, 2),
#       out_of_sample_size=0, scoring='mse', scoring_args={},
#       seasonal_order=(0, 0, 0, 1), solver='lbfgs', start_params=None,
#       suppress_warnings=True, transparams=True, trend='c')

# %%
# Forecast
n_periods = 365
fc = model.predict(n_periods=n_periods)
index_of_fc = test.index

# make series for plotting purpose
fc_series = pd.Series(fc, index=index_of_fc)

# Plot
plt.plot(ts_data.OrderVolume)
plt.plot(fc_series, color='darkgreen')
plt.title("Final Forecast of WWW Usage")
plt.show()

# %%
rms = sqrt(mean_squared_error(test.OrderVolume, fc_series))
print(rms)
# Out:
# 6.0423290207178

# %% [markdown]
# An improvement over ARIMA is **Seasonal ARIMA**. It takes into account the seasonality of dataset just like Holt's Winter method.

# %% [markdown]
# You can study more about ARIMA and Seasonal ARIMA models and it’s pre-processing from these articles :
#
# **Python** -
# https://www.analyticsvidhya.com/blog/2016/02/time-series-forecasting-codes-python/
#
# **R** -
# https://www.analyticsvidhya.com/blog/2015/12/complete-tutorial-time-series-modeling/
